# %% [markdown]
# # <p style="padding:10px;background-color:#0f4c5c;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Lung Cancer Analysis & Prediction</p>
#
# <p style="text-align:center; ">
# <img src="https://st.depositphotos.com/1909187/4810/i/450/depositphotos_48100511-stock-photo-lung-cancer-tumor-detail.jpg" style='width: 300px; height: 300px;'>
# </p>
#
#
# <p style="text-align:justify; ">
#
# Lung cancer is a type of cancer that begins in the lungs. Lungs are two spongy organs in our chest that take in oxygen when we inhale and release carbon dioxide when we exhale.
# Lung cancer is the leading cause of cancer deaths worldwide.<br>
# <br>
# People who smoke have the greatest risk of lung cancer, though lung cancer can also occur in people who have never smoked. The risk of lung cancer increases with the length of time and number of cigarettes someone's smoked. If someone quits smoking, even after smoking for many years, he/she can significantly reduce the chances of developing lung cancer.
# </p>
#
#
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:130%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Table Of Contents</p>
#
#
#
# |No  | Contents |No  | Contents  |
# |:---| :---     |:---| :----     |
# |1   | [<font color="#0f4c5c"> Importing Libraries</font>](#1)                   |12   | [<font color="#0f4c5c"> Correlation Heatmap</font>](#12)   |
# |2   | [<font color="#0f4c5c"> About Dataset</font>](#2)                         |13  | [<font color="#0f4c5c"> Preprocessing For Classification</font>](#13)|
# |3   | [<font color="#0f4c5c"> Basic Exploration</font>](#3)                     |14  | [<font color="#0f4c5c"> Logistic Regression Model</font>](#14)   |
# |4   | [<font color="#0f4c5c"> Dataset Summary</font>](#4)                       |15  | [<font color="#0f4c5c"> Gaussian Naive Bayes Model</font>](#15)    |
# |5   | [<font color="#0f4c5c"> Digging Deeper</font>](#5)      |16  | [<font color="#0f4c5c"> Bernoulli Naive Bayes Model</font>](#16)  |
# |6   | [<font color="#0f4c5c"> Custom Palette For Visualization</font>](#6)              |17  | [<font color="#0f4c5c"> Support Vector Machine Model</font>](#17)     |
# |7   | [<font color="#0f4c5c"> Positive Lung Cancer Cases</font>](#7)              |18  | [<font color="#0f4c5c"> Random Forest Model</font>](#18)     |
# |8   | [<font color="#0f4c5c"> Positive Cases' Age Distribution</font>](#8)              |19  | [<font color="#0f4c5c"> K Nearest Neighbors Model</font>](#19)     |
# |9   | [<font color="#0f4c5c"> Positive Cases' Gender Distribution</font>](#9)              |20  | [<font color="#0f4c5c"> Extreme Gradient Boosting Model</font>](#20)     |
# |10   | [<font color="#0f4c5c"> Gender-wise Positive Cases' Reasons</font>](#10)              |21  | [<font color="#0f4c5c"> Neural Network Architecture</font>](#21)     |
# |11   | [<font color="#0f4c5c"> Gender-wise Positive Cases' Symptoms</font>](#11)              |22  | [<font color="#0f4c5c"> Thank You</font>](#22)     |

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Importing Libraries</p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">About Dataset</p>

# %% [markdown]
# * **GENDER :** M [Male] , F [Female]
# * **AGE :** Age of patients
# * **SMOKING :** 2 [Yes] , 1 [No]
# * **YELLOW_FINGERS :** 2 [Yes] , 1 [No]
# * **ANXIETY :** 2 [Yes] , 1 [No]
# * **PEER_PRESSURE :** 2 [Yes] , 1 [No]
# * **CHRONIC DISEASE :** 2 [Yes] , 1 [No]
# * **FATIGUE :** 2 [Yes] , 1 [No]
# * **ALLERGY :** 2 [Yes] , 1 [No]
# * **WHEEZING :** 2 [Yes] , 1 [No]
# * **ALCOHOL CONSUMING :** 2 [Yes] , 1 [No]
# * **COUGHING :** 2 [Yes] , 1 [No]
# * **SHORTNESS OF BREATH :** 2 [Yes] , 1 [No]
# * **SWALLOWING DIFFICULTY :** 2 [Yes] , 1 [No]
# * **CHEST PAIN :** 2 [Yes] , 1 [No]
# * **LUNG_CANCER :** YES [Positive] , NO [Negative]

# %%
data = pd.read_csv("survey lung cancer.csv")

# %% [markdown]
# <a id="3"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Basic Exploration</p>
# <br>
#
# **Let's have a glimpse of the dataset.**

# %%
print(f"Shape of The Dataset : {data.shape}")
print(f"\nGlimpse of The Dataset :")
data.head().style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# Shape of The Dataset : (309, 16)
#
# Glimpse of The Dataset :
# <style type="text/css">
# #T_61233_row0_col0, #T_61233_row0_col1, #T_61233_row0_col2, #T_61233_row0_col3, #T_61233_row0_col4, #T_61233_row0_col5, #T_61233_row0_col6, #T_61233_row0_col7, #T_61233_row0_col8, #T_61233_row0_col9, #T_61233_row0_col10, #T_61233_row0_col11, #T_61233_row0_col12, #T_61233_row0_col13, #T_61233_row0_col14, #T_61233_row0_col15, #T_61233_row1_col0, #T_61233_row1_col1, #T_61233_row1_col2, #T_61233_row1_col3, #T_61233_row1_col4, #T_61233_row1_col5, #T_61233_row1_col6, #T_61233_row1_col7, #T_61233_row1_col8, #T_61233_row1_col9, #T_61233_row1_col10, #T_61233_row1_col11, #T_61233_row1_col12, #T_61233_row1_col13, #T_61233_row1_col14, #T_61233_row1_col15, #T_61233_row2_col0, #T_61233_row2_col1, #T_61233_row2_col2, #T_61233_row2_col3, #T_61233_row2_col4, #T_61233_row2_col5, #T_61233_row2_col6, #T_61233_row2_col7, #T_61233_row2_col8, #T_61233_row2_col9, #T_61233_row2_col10, #T_61233_row2_col11, #T_61233_row2_col12, #T_61233_row2_col13, #T_61233_row2_col14, #T_61233_row2_col15, #T_61233_row3_col0, #T_61233_row3_col1, #T_61233_row3_col2, #T_61233_row3_col3, #T_61233_row3_col4, #T_61233_row3_col5, #T_61233_row3_col6, #T_61233_row3_col7, #T_61233_row3_col8, #T_61233_row3_col9, #T_61233_row3_col10, #T_61233_row3_col11, #T_61233_row3_col12, #T_61233_row3_col13, #T_61233_row3_col14, #T_61233_row3_col15, #T_61233_row4_col0, #T_61233_row4_col1, #T_61233_row4_col2, #T_61233_row4_col3, #T_61233_row4_col4, #T_61233_row4_col5, #T_61233_row4_col6, #T_61233_row4_col7, #T_61233_row4_col8, #T_61233_row4_col9, #T_61233_row4_col10, #T_61233_row4_col11, #T_61233_row4_col12, #T_61233_row4_col13, #T_61233_row4_col14, #T_61233_row4_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_61233_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >GENDER</th>
#       <th class="col_heading level0 col1" >AGE</th>
#       <th class="col_heading level0 col2" >SMOKING</th>
#       <th class="col_heading level0 col3" >YELLOW_FINGERS</th>
#       <th class="col_heading level0 col4" >ANXIETY</th>
#       <th class="col_heading level0 col5" >PEER_PRESSURE</th>
#       <th class="col_heading level0 col6" >CHRONIC DISEASE</th>
#       <th class="col_heading level0 col7" >FATIGUE </th>
#       <th class="col_heading level0 col8" >ALLERGY </th>
#       <th class="col_heading level0 col9" >WHEEZING</th>
#       <th class="col_heading level0 col10" >ALCOHOL CONSUMING</th>
#       <th class="col_heading level0 col11" >COUGHING</th>
#       <th class="col_heading level0 col12" >SHORTNESS OF BREATH</th>
#       <th class="col_heading level0 col13" >SWALLOWING DIFFICULTY</th>
#       <th class="col_heading level0 col14" >CHEST PAIN</th>
#       <th class="col_heading level0 col15" >LUNG_CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61233_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61233_row0_col0" class="data row0 col0" >M</td>
#       <td id="T_61233_row0_col1" class="data row0 col1" >69</td>
#       <td id="T_61233_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_61233_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_61233_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_61233_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_61233_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_61233_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_61233_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_61233_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_61233_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_61233_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_61233_row0_col12" class="data row0 col12" >2</td>
#       <td id="T_61233_row0_col13" class="data row0 col13" >2</td>
#       <td id="T_61233_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_61233_row0_col15" class="data row0 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_61233_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_61233_row1_col0" class="data row1 col0" >M</td>
#       <td id="T_61233_row1_col1" class="data row1 col1" >74</td>
#       <td id="T_61233_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_61233_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_61233_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_61233_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_61233_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_61233_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_61233_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_61233_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_61233_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_61233_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_61233_row1_col12" class="data row1 col12" >2</td>
#       <td id="T_61233_row1_col13" class="data row1 col13" >2</td>
#       <td id="T_61233_row1_col14" class="data row1 col14" >2</td>
#       <td id="T_61233_row1_col15" class="data row1 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_61233_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_61233_row2_col0" class="data row2 col0" >F</td>
#       <td id="T_61233_row2_col1" class="data row2 col1" >59</td>
#       <td id="T_61233_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_61233_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_61233_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_61233_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_61233_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_61233_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_61233_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_61233_row2_col9" class="data row2 col9" >2</td>
#       <td id="T_61233_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_61233_row2_col11" class="data row2 col11" >2</td>
#       <td id="T_61233_row2_col12" class="data row2 col12" >2</td>
#       <td id="T_61233_row2_col13" class="data row2 col13" >1</td>
#       <td id="T_61233_row2_col14" class="data row2 col14" >2</td>
#       <td id="T_61233_row2_col15" class="data row2 col15" >NO</td>
#     </tr>
#     <tr>
#       <th id="T_61233_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_61233_row3_col0" class="data row3 col0" >M</td>
#       <td id="T_61233_row3_col1" class="data row3 col1" >63</td>
#       <td id="T_61233_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_61233_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_61233_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_61233_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_61233_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_61233_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_61233_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_61233_row3_col9" class="data row3 col9" >1</td>
#       <td id="T_61233_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_61233_row3_col11" class="data row3 col11" >1</td>
#       <td id="T_61233_row3_col12" class="data row3 col12" >1</td>
#       <td id="T_61233_row3_col13" class="data row3 col13" >2</td>
#       <td id="T_61233_row3_col14" class="data row3 col14" >2</td>
#       <td id="T_61233_row3_col15" class="data row3 col15" >NO</td>
#     </tr>
#     <tr>
#       <th id="T_61233_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_61233_row4_col0" class="data row4 col0" >F</td>
#       <td id="T_61233_row4_col1" class="data row4 col1" >63</td>
#       <td id="T_61233_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_61233_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_61233_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_61233_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_61233_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_61233_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_61233_row4_col8"

# %%
print(f"Dataset Size : {data.shape}")
print(f"\nLung Cancer Dataset :")
data.head()
# Out:
# Dataset Size : (309, 16)
#
# Lung Cancer Dataset :
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2         YES
# 1                    2                      2           2         YES
# 2                    2                      1           2          NO
# 3                    1                      2           2          NO
# 4                    2                      1           1          NO

# %%
print(f"Information About The Dataset :\n")
print(data.info())
# Out:
# Information About The Dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
#  15  LUNG_CANCER            309 non-null    object
# dtypes: int64(14), object(2)
# memory usage: 38.8+ KB
# None

# %% [markdown]
# <a id="4"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Dataset Summary</p>

# %%
print(f"Summary of This Dataset :")
data.describe()
# Out:
# Summary of This Dataset :
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  276.000000  276.000000      276.000000  276.000000     276.000000
# mean    62.909420    1.543478        1.576087    1.496377       1.507246
# std      8.379355    0.499011        0.495075    0.500895       0.500856
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.750000    1.000000        1.000000    1.000000       1.000000
# 50%     62.500000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING  \
# count       276.000000  276.000000  276.000000  276.000000         276.000000
# mean          1.521739    1.663043    1.547101    1.547101           1.550725
# std           0.500435    0.473529    0.498681    0.498681           0.498324
# min           1.000000    1.000000    1.000000    1.000000           1.000000
# 25%           1.000000    1.000000    1.000000    1.000000           1.000000
# 50%           2.000000    2.000000    2.000000    2.000000           2.000000
# 75%           2.000000    2.000000    2.000000    2.000000           2.000000
# max           2.000000    2.000000    2.000000    2.000000           2.000000
#
#          COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN
# count  276.000000           276.000000             276.000000  276.000000
# mean     1.576087             1.630435               1.467391    1.557971
# std      0.495075             0.483564               0.499842    0.497530
# min      1.000000             1.000000               1.000000    1.000000
# 25%      1.000000             1.000000               1.000000    1.000000
# 50%      2.000000             2.000000               1.000000    2.000000
# 75%      2.000000             2.000000               2.000000    2.000000
# max      2.000000             2.000000               2.000000    2.000000

# %%
data.describe(include=object)
# Out:
#        GENDER LUNG_CANCER
# count     276         276
# unique      2           2
# top         M         YES
# freq      142         238

# %%
data.isna().sum().to_frame()
# Out:
#                        0
# GENDER                 0
# AGE                    0
# SMOKING                0
# YELLOW_FINGERS         0
# ANXIETY                0
# PEER_PRESSURE          0
# CHRONIC DISEASE        0
# FATIGUE                0
# ALLERGY                0
# WHEEZING               0
# ALCOHOL CONSUMING      0
# COUGHING               0
# SHORTNESS OF BREATH    0
# SWALLOWING DIFFICULTY  0
# CHEST PAIN             0
# LUNG_CANCER            0

# %% [markdown]
# Here, we can see there is **no null value** exists in this dataset. Let's check if there exists any duplicate entry in this dataset. If exists then we will remove them from the dataset. After that we will initialize the visualization style and custom pallete for visualization.

# %%
dup = data[data.duplicated()].shape[0]
print(f"There are {dup} duplicate rows among {data.shape[0]} entries in this dataset.")

data.drop_duplicates(keep='first',inplace=True)
print(f"\nAfter removing duplicate rows there are {data.shape[0]} entries in this dataset.")
# Out:
# There are 33 duplicate rows among 309 entries in this dataset.
#
# After removing duplicate rows there are 276 entries in this dataset.

# %% [markdown]
# <a id="5"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Digging Deeper</p>

# %% [markdown]
# Let's replace all the **numeric values** into **categorical values** for better and efficient visualization. All the **2**'s and **1**'s will be replaced by **"YES"** and **"NO"** accordingly. And replace **"M"** and **"F"** by **"Male"** and **"Female"** accordingly in **"GENDER"** column.

# %%
data_temp = data.copy()
data_temp["GENDER"] = data_temp["GENDER"].replace({"M" : "Male" , "F" : "Female"})

for column in data_temp.columns:
    data_temp[column] = data_temp[column].replace({2: "Yes" , 1 : "No"})

data_temp.head()
# Out:
#    GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC DISEASE  \
# 0    Male   69      No            Yes     Yes            No              No
# 1    Male   74     Yes             No      No            No             Yes
# 2  Female   59      No             No      No           Yes              No
# 3    Male   63     Yes            Yes     Yes            No              No
# 4  Female   63      No            Yes      No            No              No
#
#   FATIGUE  ALLERGY  WHEEZING ALCOHOL CONSUMING COUGHING SHORTNESS OF BREATH  \
# 0      Yes       No      Yes               Yes      Yes                 Yes
# 1      Yes      Yes       No                No       No                 Yes
# 2      Yes       No      Yes                No      Yes                 Yes
# 3       No       No       No               Yes       No                  No
# 4       No       No      Yes                No      Yes                 Yes
#
#   SWALLOWING DIFFICULTY CHEST PAIN LUNG_CANCER
# 0                   Yes        Yes         YES
# 1                   Yes        Yes         YES
# 2                    No        Yes          NO
# 3                   Yes        Yes          NO
# 4                    No         No          NO

# %% [markdown]
# <a id="6"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Custom Palette For Visualization</p>

# %%
sns.set_style("whitegrid")
sns.set_context("poster",font_scale = .7)

palette = ["#1d7874","#679289","#f4c095","#ee2e31","#ffb563","#918450","#f85e00","#a41623","#9a031e","#d6d6d6","#ffee32","#ffd100","#333533","#202020"]

# sns.palplot(sns.color_palette(palette))
# plt.show()

# %% [markdown]
# <a id="7"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Positive Lung Cancer Cases</p>

# %% [markdown]
# Let's create a new dataframe containing only positive cases data.

# %%
data_temp_pos = data_temp[data_temp["LUNG_CANCER"] == "YES"]
data_temp_pos.head().style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_c1ea2_row0_col0, #T_c1ea2_row0_col1, #T_c1ea2_row0_col2, #T_c1ea2_row0_col3, #T_c1ea2_row0_col4, #T_c1ea2_row0_col5, #T_c1ea2_row0_col6, #T_c1ea2_row0_col7, #T_c1ea2_row0_col8, #T_c1ea2_row0_col9, #T_c1ea2_row0_col10, #T_c1ea2_row0_col11, #T_c1ea2_row0_col12, #T_c1ea2_row0_col13, #T_c1ea2_row0_col14, #T_c1ea2_row0_col15, #T_c1ea2_row1_col0, #T_c1ea2_row1_col1, #T_c1ea2_row1_col2, #T_c1ea2_row1_col3, #T_c1ea2_row1_col4, #T_c1ea2_row1_col5, #T_c1ea2_row1_col6, #T_c1ea2_row1_col7, #T_c1ea2_row1_col8, #T_c1ea2_row1_col9, #T_c1ea2_row1_col10, #T_c1ea2_row1_col11, #T_c1ea2_row1_col12, #T_c1ea2_row1_col13, #T_c1ea2_row1_col14, #T_c1ea2_row1_col15, #T_c1ea2_row2_col0, #T_c1ea2_row2_col1, #T_c1ea2_row2_col2, #T_c1ea2_row2_col3, #T_c1ea2_row2_col4, #T_c1ea2_row2_col5, #T_c1ea2_row2_col6, #T_c1ea2_row2_col7, #T_c1ea2_row2_col8, #T_c1ea2_row2_col9, #T_c1ea2_row2_col10, #T_c1ea2_row2_col11, #T_c1ea2_row2_col12, #T_c1ea2_row2_col13, #T_c1ea2_row2_col14, #T_c1ea2_row2_col15, #T_c1ea2_row3_col0, #T_c1ea2_row3_col1, #T_c1ea2_row3_col2, #T_c1ea2_row3_col3, #T_c1ea2_row3_col4, #T_c1ea2_row3_col5, #T_c1ea2_row3_col6, #T_c1ea2_row3_col7, #T_c1ea2_row3_col8, #T_c1ea2_row3_col9, #T_c1ea2_row3_col10, #T_c1ea2_row3_col11, #T_c1ea2_row3_col12, #T_c1ea2_row3_col13, #T_c1ea2_row3_col14, #T_c1ea2_row3_col15, #T_c1ea2_row4_col0, #T_c1ea2_row4_col1, #T_c1ea2_row4_col2, #T_c1ea2_row4_col3, #T_c1ea2_row4_col4, #T_c1ea2_row4_col5, #T_c1ea2_row4_col6, #T_c1ea2_row4_col7, #T_c1ea2_row4_col8, #T_c1ea2_row4_col9, #T_c1ea2_row4_col10, #T_c1ea2_row4_col11, #T_c1ea2_row4_col12, #T_c1ea2_row4_col13, #T_c1ea2_row4_col14, #T_c1ea2_row4_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_c1ea2_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >GENDER</th>
#       <th class="col_heading level0 col1" >AGE</th>
#       <th class="col_heading level0 col2" >SMOKING</th>
#       <th class="col_heading level0 col3" >YELLOW_FINGERS</th>
#       <th class="col_heading level0 col4" >ANXIETY</th>
#       <th class="col_heading level0 col5" >PEER_PRESSURE</th>
#       <th class="col_heading level0 col6" >CHRONIC DISEASE</th>
#       <th class="col_heading level0 col7" >FATIGUE </th>
#       <th class="col_heading level0 col8" >ALLERGY </th>
#       <th class="col_heading level0 col9" >WHEEZING</th>
#       <th class="col_heading level0 col10" >ALCOHOL CONSUMING</th>
#       <th class="col_heading level0 col11" >COUGHING</th>
#       <th class="col_heading level0 col12" >SHORTNESS OF BREATH</th>
#       <th class="col_heading level0 col13" >SWALLOWING DIFFICULTY</th>
#       <th class="col_heading level0 col14" >CHEST PAIN</th>
#       <th class="col_heading level0 col15" >LUNG_CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1ea2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1ea2_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_c1ea2_row0_col1" class="data row0 col1" >69</td>
#       <td id="T_c1ea2_row0_col2" class="data row0 col2" >No</td>
#       <td id="T_c1ea2_row0_col3" class="data row0 col3" >Yes</td>
#       <td id="T_c1ea2_row0_col4" class="data row0 col4" >Yes</td>
#       <td id="T_c1ea2_row0_col5" class="data row0 col5" >No</td>
#       <td id="T_c1ea2_row0_col6" class="data row0 col6" >No</td>
#       <td id="T_c1ea2_row0_col7" class="data row0 col7" >Yes</td>
#       <td id="T_c1ea2_row0_col8" class="data row0 col8" >No</td>
#       <td id="T_c1ea2_row0_col9" class="data row0 col9" >Yes</td>
#       <td id="T_c1ea2_row0_col10" class="data row0 col10" >Yes</td>
#       <td id="T_c1ea2_row0_col11" class="data row0 col11" >Yes</td>
#       <td id="T_c1ea2_row0_col12" class="data row0 col12" >Yes</td>
#       <td id="T_c1ea2_row0_col13" class="data row0 col13" >Yes</td>
#       <td id="T_c1ea2_row0_col14" class="data row0 col14" >Yes</td>
#       <td id="T_c1ea2_row0_col15" class="data row0 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_c1ea2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c1ea2_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_c1ea2_row1_col1" class="data row1 col1" >74</td>
#       <td id="T_c1ea2_row1_col2" class="data row1 col2" >Yes</td>
#       <td id="T_c1ea2_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_c1ea2_row1_col4" class="data row1 col4" >No</td>
#       <td id="T_c1ea2_row1_col5" class="data row1 col5" >No</td>
#       <td id="T_c1ea2_row1_col6" class="data row1 col6" >Yes</td>
#       <td id="T_c1ea2_row1_col7" class="data row1 col7" >Yes</td>
#       <td id="T_c1ea2_row1_col8" class="data row1 col8" >Yes</td>
#       <td id="T_c1ea2_row1_col9" class="data row1 col9" >No</td>
#       <td id="T_c1ea2_row1_col10" class="data row1 col10" >No</td>
#       <td id="T_c1ea2_row1_col11" class="data row1 col11" >No</td>
#       <td id="T_c1ea2_row1_col12" class="data row1 col12" >Yes</td>
#       <td id="T_c1ea2_row1_col13" class="data row1 col13" >Yes</td>
#       <td id="T_c1ea2_row1_col14" class="data row1 col14" >Yes</td>
#       <td id="T_c1ea2_row1_col15" class="data row1 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_c1ea2_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_c1ea2_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_c1ea2_row2_col1" class="data row2 col1" >75</td>
#       <td id="T_c1ea2_row2_col2" class="data row2 col2" >No</td>
#       <td id="T_c1ea2_row2_col3" class="data row2 col3" >Yes</td>
#       <td id="T_c1ea2_row2_col4" class="data row2 col4" >No</td>
#       <td id="T_c1ea2_row2_col5" class="data row2 col5" >No</td>
#       <td id="T_c1ea2_row2_col6" class="data row2 col6" >Yes</td>
#       <td id="T_c1ea2_row2_col7" class="data row2 col7" >Yes</td>
#       <td id="T_c1ea2_row2_col8" class="data row2 col8" >Yes</td>
#       <td id="T_c1ea2_row2_col9" class="data row2 col9" >Yes</td>
#       <td id="T_c1ea2_row2_col10" class="data row2 col10" >No</td>
#       <td id="T_c1ea2_row2_col11" class="data row2 col11" >Yes</td>
#       <td id="T_c1ea2_row2_col12" class="data row2 col12" >Yes</td>
#       <td id="T_c1ea2_row2_col13" class="data row2 col13" >No</td>
#       <td id="T_c1ea2_row2_col14" class="data row2 col14" >No</td>
#       <td id="T_c1ea2_row2_col15" class="data row2 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_c1ea2_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_c1ea2_row3_col0" class="data row3 col0" >Male</td>
#       <td id="T_c1ea2_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_c1ea2_row3_col2" class="data row3 col2" >Yes</td>
#       <td id="T_c1ea2_row3_col3" class="data row3 col3" >No</td>
#       <td id="T_c1ea2_row3_col4" class="data row3 col4" >No</td>
#       <td id="T_c1ea2_row3_col5" class="data row3 col5" >No</td>
#       <td id="T_c1ea2_row3_col6" class="data row3 col6" >No</td>
#       <td id="T_c1ea2_row3_col7" class="data row3 col7" >Yes</td>
#       <td id="T_c1ea2_row3_col8" class="data row3 col8" >No</td>
#       <td id="T_c1ea2_row3_col9" class="data row3 col9" >Yes</td>
#       <td id="T_c1ea2_row3_col10" class="data row3 col10" >Yes</td>
#       <td id="T_c1ea2_row3_col11" class="data row3 col11" >Yes</td>
#       <td id="T_c1ea2_row3_col12" class="data row3 col12" >Yes</td>
#       <td id="T_c1ea2_row3_col13" class="data row3 col13" >No</td>
#       <td id="T_c1ea2_row3_col14" class="data row3 col14" >Yes</td>
#       <td id="T_c1ea2_row3_col15" class="data row3 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_c1ea2_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_c1ea2_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_c1ea2_row4_col1" class="data row4 col1" >51</td>
#       <td id="T_c1ea2_row4_col2" class="data row4 col2" >Yes</td>
#       <td id="T_c1ea2_row4_col3" class="data row4 col3" >Yes</td>
#       <td id="T_c1ea2_row4_col4" class="data row4 col4" >Yes</td>
#       <td id="T_c1ea2_row4_col5" class="data row4 col5" >Yes</td>
#       <td id="T_c1ea2_row4_col6" class="data row4

# %% [markdown]
# <a id="8"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Positive Cases' Age Distribution</p>

# %%
_, axs = plt.subplots(2,1,figsize=(20,10),sharex=True,sharey=True)
plt.tight_layout(pad=4.0)

sns.histplot(data_temp_pos[data_temp_pos["GENDER"]=="Male"]["AGE"],color=palette[11],kde=True,ax=axs[0],bins=20,alpha=1,fill=True)
axs[0].lines[0].set_color(palette[12])
axs[0].set_title("\nPositive Male Cases Age Distribution\n",fontsize=20)
axs[0].set_xlabel("Age")
axs[0].set_ylabel("Quantity")

sns.histplot(data_temp_pos[data_temp_pos["GENDER"]=="Female"]["AGE"],color=palette[12],kde=True,ax=axs[1],bins=20,alpha=1,fill=True)
axs[1].lines[0].set_color(palette[11])
axs[1].set_title("\nPositive Female Cases Age Distribution\n",fontsize=20)
axs[1].set_xlabel("Age")
axs[1].set_ylabel("Quantity")

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# **Let's stack them together in a same figure.**

# %%
plt.subplots(figsize=(20, 8))
p = sns.histplot(data=data_temp_pos,x="AGE",hue="GENDER",multiple="stack",palette=palette[11:13],kde=True,shrink=.99,bins=20,alpha=1,fill=True)
p.axes.lines[0].set_color(palette[11])
p.axes.lines[1].set_color(palette[12])
p.axes.set_title("\nPositive Cases Age Distribution\n",fontsize=20)
plt.ylabel("Count")
plt.xlabel("Age")

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# <a id="9"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Positive Cases' Gender Distribution</p>

# %%
plt.subplots(figsize=(12, 12))

labels = "Male","Female"
size = 0.5

wedges, texts, autotexts = plt.pie([len(data_temp_pos[data_temp_pos["GENDER"]=="Male"]["GENDER"]),
                                    len(data_temp_pos[data_temp_pos["GENDER"]=="Female"]["GENDER"])],
                                    explode = (0,0),
                                    textprops=dict(size= 25, color= "white"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.7,
                                    radius=.9, 
                                    colors = ["#0f4c5c","#FFC300"], 
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "white", 
                                    linewidth = 5),
                                    startangle = 0)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))
plt.title("\nPositive Cases' Gender Distribution",fontsize=20)
plt.show()

# %% [markdown]
# <a id="10"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Gender-wise Positive Cases' Reasons</p>

# %%
_, axs = plt.subplots(1,2,figsize=(20,8),sharex=True,sharey=True)
plt.tight_layout(pad=4.0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="SMOKING",hue_order=["Yes","No"],ax=axs[0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0].set_title("\nEffect of Smoking\n",fontsize=20)
axs[0].set_xlabel("Gender")
axs[0].set_ylabel("Quantity")
for container in axs[0].containers:
    axs[0].bar_label(container,label_type="center",padding=2,size=25,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="ALCOHOL CONSUMING",hue_order=["Yes","No"],ax=axs[1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1].set_title("\nEffect of Alcohol Consuming\n",fontsize=20)
axs[1].set_xlabel("Gender")
axs[1].set_ylabel("Quantity")
for container in axs[1].containers:
    axs[1].bar_label(container,label_type="center",padding=2,size=25,color="white",rotation=0)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-96f8cb4750c4> in <module>
#       7 axs[0].set_ylabel("Quantity")
#       8 for container in axs[0].containers:
# ----> 9     axs[0].bar_label(container,label_type="center",padding=2,size=25,color="white",rotation=0)
#      10
#      11 sns.countplot(data=data_temp_pos,x="GENDER",hue="ALCOHOL CONSUMING",hue_order=["Yes","No"],ax=axs[1],palette=["#0f4c5c","#FFC300"],saturation=1)
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %% [markdown]
# <a id="11"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Gender-wise Positive Cases' Symptoms</p>

# %%
_, axs = plt.subplots(2,5,figsize=(20,14),sharex=False,sharey=True)
plt.tight_layout(pad=4.0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="YELLOW_FINGERS",hue_order=["Yes","No"],ax=axs[0,0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,0].set_ylabel("Total")
axs[0,0].legend(title="Yellow Fingers",loc="upper right")
for container in axs[0,0].containers:
    axs[0,0].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="ANXIETY",hue_order=["Yes","No"],ax=axs[0,1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,1].set_ylabel("Total")
axs[0,1].legend(title="Anxiety",loc="upper right")
for container in axs[0,1].containers:
    axs[0,1].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="CHRONIC DISEASE",hue_order=["Yes","No"],ax=axs[0,2],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,2].set_ylabel("Total")
axs[0,2].legend(title="Chronic Disease",loc="upper right")
for container in axs[0,2].containers:
    axs[0,2].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="CHEST PAIN",hue_order=["Yes","No"],ax=axs[0,3],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,3].set_ylabel("Total")
axs[0,3].legend(title="Chest Pain",loc="upper right")
for container in axs[0,3].containers:
    axs[0,3].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="FATIGUE ",hue_order=["Yes","No"],ax=axs[0,4],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,4].set_ylabel("Total")
axs[0,4].legend(title="Fatigue",loc="upper right")
for container in axs[0,4].containers:
    axs[0,4].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="WHEEZING",hue_order=["Yes","No"],ax=axs[1,0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,0].set_ylabel("Total")
axs[1,0].legend(title="Wheezing",loc="upper right")
for container in axs[1,0].containers:
    axs[1,0].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="COUGHING",hue_order=["Yes","No"],ax=axs[1,1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,1].set_ylabel("Total")
axs[1,1].legend(title="Coughing",loc="upper right")
for container in axs[1,1].containers:
    axs[1,1].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="SHORTNESS OF BREATH",hue_order=["Yes","No"],ax=axs[1,2],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,2].set_ylabel("Total")
axs[1,2].legend(title="Short Breath",loc="upper right")
for container in axs[1,2].containers:
    axs[1,2].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="SWALLOWING DIFFICULTY",hue_order=["Yes","No"],ax=axs[1,3],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,3].set_ylabel("Total")
axs[1,3].legend(title="Swallowing Difficulty",loc="upper right")
for container in axs[1,3].containers:
    axs[1,3].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)    

sns.countplot(data=data_temp_pos,x="GENDER",hue="ALLERGY ",hue_order=["Yes","No"],ax=axs[1,4],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,4].set_ylabel("Total")
axs[1,4].legend(title="Allergy",loc="upper right")
for container in axs[1,4].containers:
    axs[1,4].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)    

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-1e1a2a88ca91> in <module>
#       6 axs[0,0].legend(title="Yellow Fingers",loc="upper right")
#       7 for container in axs[0,0].containers:
# ----> 8     axs[0,0].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)
#       9
#      10 sns.countplot(data=data_temp_pos,x="GENDER",hue="ANXIETY",hue_order=["Yes","No"],ax=axs[0,1],palette=["#0f4c5c","#FFC300"],saturation=1)
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %% [markdown]
# <a id="12"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Correlation Heatmap</p>

# %% [markdown]
# Let's convert the target feature **"LUNG_CANCER"** from **Categorical** to **Numerical** data type by using **Label Encoder**. And converting the **"GENDER"** column from **Categorical** to **Numerical** data type by using **"One Hot Encoder"** for avoiding unexpected gender bias.

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder = LabelEncoder()

data["GENDER"] = data["GENDER"].replace({"M" : "Male" , "F" : "Female"})
data["LUNG_CANCER"] = LabelEncoder.fit_transform(data["LUNG_CANCER"])

data = pd.get_dummies(data, columns= ["GENDER"])
data.rename(columns={"GENDER_Male" : "MALE", "GENDER_Female" : "FEMALE", "YELLOW_FINGERS" : "YELLOW FINGERS", "PEER_PRESSURE" : "PEER PRESSURE", "LUNG_CANCER" : "LUNG CANCER", "FATIGUE " : "FATIGUE", "ALLERGY " : "ALLERGY"}, inplace=True)
data = data[["AGE","MALE","FEMALE","ALCOHOL CONSUMING","CHEST PAIN","SHORTNESS OF BREATH","COUGHING","PEER PRESSURE","CHRONIC DISEASE","SWALLOWING DIFFICULTY","YELLOW FINGERS","ANXIETY","FATIGUE","ALLERGY","WHEEZING","LUNG CANCER"]]
data.head().style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_e412a_row0_col0, #T_e412a_row0_col1, #T_e412a_row0_col2, #T_e412a_row0_col3, #T_e412a_row0_col4, #T_e412a_row0_col5, #T_e412a_row0_col6, #T_e412a_row0_col7, #T_e412a_row0_col8, #T_e412a_row0_col9, #T_e412a_row0_col10, #T_e412a_row0_col11, #T_e412a_row0_col12, #T_e412a_row0_col13, #T_e412a_row0_col14, #T_e412a_row0_col15, #T_e412a_row1_col0, #T_e412a_row1_col1, #T_e412a_row1_col2, #T_e412a_row1_col3, #T_e412a_row1_col4, #T_e412a_row1_col5, #T_e412a_row1_col6, #T_e412a_row1_col7, #T_e412a_row1_col8, #T_e412a_row1_col9, #T_e412a_row1_col10, #T_e412a_row1_col11, #T_e412a_row1_col12, #T_e412a_row1_col13, #T_e412a_row1_col14, #T_e412a_row1_col15, #T_e412a_row2_col0, #T_e412a_row2_col1, #T_e412a_row2_col2, #T_e412a_row2_col3, #T_e412a_row2_col4, #T_e412a_row2_col5, #T_e412a_row2_col6, #T_e412a_row2_col7, #T_e412a_row2_col8, #T_e412a_row2_col9, #T_e412a_row2_col10, #T_e412a_row2_col11, #T_e412a_row2_col12, #T_e412a_row2_col13, #T_e412a_row2_col14, #T_e412a_row2_col15, #T_e412a_row3_col0, #T_e412a_row3_col1, #T_e412a_row3_col2, #T_e412a_row3_col3, #T_e412a_row3_col4, #T_e412a_row3_col5, #T_e412a_row3_col6, #T_e412a_row3_col7, #T_e412a_row3_col8, #T_e412a_row3_col9, #T_e412a_row3_col10, #T_e412a_row3_col11, #T_e412a_row3_col12, #T_e412a_row3_col13, #T_e412a_row3_col14, #T_e412a_row3_col15, #T_e412a_row4_col0, #T_e412a_row4_col1, #T_e412a_row4_col2, #T_e412a_row4_col3, #T_e412a_row4_col4, #T_e412a_row4_col5, #T_e412a_row4_col6, #T_e412a_row4_col7, #T_e412a_row4_col8, #T_e412a_row4_col9, #T_e412a_row4_col10, #T_e412a_row4_col11, #T_e412a_row4_col12, #T_e412a_row4_col13, #T_e412a_row4_col14, #T_e412a_row4_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_e412a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >AGE</th>
#       <th class="col_heading level0 col1" >MALE</th>
#       <th class="col_heading level0 col2" >FEMALE</th>
#       <th class="col_heading level0 col3" >ALCOHOL CONSUMING</th>
#       <th class="col_heading level0 col4" >CHEST PAIN</th>
#       <th class="col_heading level0 col5" >SHORTNESS OF BREATH</th>
#       <th class="col_heading level0 col6" >COUGHING</th>
#       <th class="col_heading level0 col7" >PEER PRESSURE</th>
#       <th class="col_heading level0 col8" >CHRONIC DISEASE</th>
#       <th class="col_heading level0 col9" >SWALLOWING DIFFICULTY</th>
#       <th class="col_heading level0 col10" >YELLOW FINGERS</th>
#       <th class="col_heading level0 col11" >ANXIETY</th>
#       <th class="col_heading level0 col12" >FATIGUE</th>
#       <th class="col_heading level0 col13" >ALLERGY</th>
#       <th class="col_heading level0 col14" >WHEEZING</th>
#       <th class="col_heading level0 col15" >LUNG CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e412a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e412a_row0_col0" class="data row0 col0" >69</td>
#       <td id="T_e412a_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_e412a_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_e412a_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_e412a_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_e412a_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_e412a_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_e412a_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_e412a_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_e412a_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_e412a_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_e412a_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_e412a_row0_col12" class="data row0 col12" >2</td>
#       <td id="T_e412a_row0_col13" class="data row0 col13" >1</td>
#       <td id="T_e412a_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_e412a_row0_col15" class="data row0 col15" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e412a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e412a_row1_col0" class="data row1 col0" >74</td>
#       <td id="T_e412a_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_e412a_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_e412a_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_e412a_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_e412a_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_e412a_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_e412a_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_e412a_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_e412a_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_e412a_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_e412a_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_e412a_row1_col12" class="data row1 col12" >2</td>
#       <td id="T_e412a_row1_col13" class="data row1 col13" >2</td>
#       <td id="T_e412a_row1_col14" class="data row1 col14" >1</td>
#       <td id="T_e412a_row1_col15" class="data row1 col15" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e412a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e412a_row2_col0" class="data row2 col0" >59</td>
#       <td id="T_e412a_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_e412a_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_e412a_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_e412a_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_e412a_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_e412a_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_e412a_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_e412a_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_e412a_row2_col9" class="data row2 col9" >1</td>
#       <td id="T_e412a_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_e412a_row2_col11" class="data row2 col11" >1</td>
#       <td id="T_e412a_row2_col12" class="data row2 col12" >2</td>
#       <td id="T_e412a_row2_col13" class="data row2 col13" >1</td>
#       <td id="T_e412a_row2_col14" class="data row2 col14" >2</td>
#       <td id="T_e412a_row2_col15" class="data row2 col15" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e412a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e412a_row3_col0" class="data row3 col0" >63</td>
#       <td id="T_e412a_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_e412a_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_e412a_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_e412a_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_e412a_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_e412a_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_e412a_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_e412a_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_e412a_row3_col9" class="data row3 col9" >2</td>
#       <td id="T_e412a_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_e412a_row3_col11" class="data row3 col11" >2</td>
#       <td id="T_e412a_row3_col12" class="data row3 col12" >1</td>
#       <td id="T_e412a_row3_col13" class="data row3 col13" >1</td>
#       <td id="T_e412a_row3_col14" class="data row3 col14" >1</td>
#       <td id="T_e412a_row3_col15" class="data row3 col15" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e412a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e412a_row4_col0" class="data row4 col0" >63</td>
#       <td id="T_e412a_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_e412a_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_e412a_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_e412a_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_e412a_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_e412a_row4_col6" class="data row4 col6" >2</td>
#       <td id="T_e412a_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_e412a_row4_col8" class="data row4 col8" >1</td

# %%
plt.subplots(figsize =(16, 12))

p=sns.heatmap(data.corr(), cmap = palette, square=True, cbar_kws=dict(shrink =.99), 
            annot=True, vmin=-1, vmax=1, linewidths=0.1,linecolor='white',annot_kws=dict(fontsize =12))
p.axes.set_title("Pearson Correlation Of Features\n", fontsize=25)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <a id="13"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Preprocessing For Classification</p>

# %%
x = data.drop("LUNG CANCER", axis = 1)
y = data["LUNG CANCER"]

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
x = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

print(f"Shape of training data : {x_train.shape}, {y_train.shape}")
print(f"Shape of testing data : {x_test.shape}, {y_test.shape}")
# Out:
# Shape of training data : (220, 15), (220,)
# Shape of testing data : (56, 15), (56,)

# %% [markdown]
# <a id="14"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Logistic Regression Model</p>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


lr = LogisticRegression()
lr.fit(x_train, y_train)
lr_pred = lr.predict(x_test)
lr_conf = confusion_matrix(y_test, lr_pred)
lr_report = classification_report(y_test, lr_pred)
lr_acc = round(accuracy_score(y_test, lr_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{lr_conf}")
print(f"\nClassification Report : \n\n{lr_report}")
print(f"\nThe Accuracy of Logistic Regression is {lr_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 5  7]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.42      0.59        12
#            1       0.86      1.00      0.93        44
#
#     accuracy                           0.88        56
#    macro avg       0.93      0.71      0.76        56
# weighted avg       0.89      0.88      0.85        56
#
#
# The Accuracy of Logistic Regression is 87.5 %

# %% [markdown]
# <a id="15"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Gaussian Naive Bayes Model</p>

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(x_train, y_train)
gnb_pred = gnb.predict(x_test)
gnb_conf = confusion_matrix(y_test, gnb_pred)
gnb_report = classification_report(y_test, gnb_pred)
gnb_acc = round(accuracy_score(y_test, gnb_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{gnb_conf}")
print(f"\nClassification Report : \n\n{gnb_report}")
print(f"\nThe Accuracy of Gaussian Naive Bayes is {gnb_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 8  4]
#  [ 1 43]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.76        12
#            1       0.91      0.98      0.95        44
#
#     accuracy                           0.91        56
#    macro avg       0.90      0.82      0.85        56
# weighted avg       0.91      0.91      0.91        56
#
#
# The Accuracy of Gaussian Naive Bayes is 91.07 %

# %% [markdown]
# <a id="16"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Bernoulli Naive Bayes Model</p>

# %%
from sklearn.naive_bayes import BernoulliNB

bnb = BernoulliNB()
bnb.fit(x_train, y_train)
bnb_pred = bnb.predict(x_test)
bnb_conf = confusion_matrix(y_test, bnb_pred)
bnb_report = classification_report(y_test, bnb_pred)
bnb_acc = round(accuracy_score(y_test, bnb_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{bnb_conf}")
print(f"\nClassification Report : \n\n{bnb_report}")
print(f"\nThe Accuracy of Bernoulli Naive Bayes is {bnb_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 8  4]
#  [ 1 43]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.76        12
#            1       0.91      0.98      0.95        44
#
#     accuracy                           0.91        56
#    macro avg       0.90      0.82      0.85        56
# weighted avg       0.91      0.91      0.91        56
#
#
# The Accuracy of Bernoulli Naive Bayes is 91.07 %

# %% [markdown]
# <a id="17"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Support Vector Machine Model</p>

# %%
from sklearn.svm import SVC

svm = SVC(C = 100, gamma = 0.002)
svm.fit(x_train, y_train)
svm_pred = svm.predict(x_test)
svm_conf = confusion_matrix(y_test, svm_pred)
svm_report = classification_report(y_test, svm_pred)
svm_acc = round(accuracy_score(y_test, svm_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{svm_conf}")
print(f"\nClassification Report : \n\n{svm_report}")
print(f"\nThe Accuracy of Support Vector Machine is {svm_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 4  8]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50        12
#            1       0.85      1.00      0.92        44
#
#     accuracy                           0.86        56
#    macro avg       0.92      0.67      0.71        56
# weighted avg       0.88      0.86      0.83        56
#
#
# The Accuracy of Support Vector Machine is 85.71 %

# %% [markdown]
# <a id="18"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Random Forest Model</p>

# %%
from sklearn.ensemble import RandomForestClassifier

rfg = RandomForestClassifier(n_estimators = 100, random_state = 42) 
rfg.fit(x_train, y_train)
rfg_pred = rfg.predict(x_test)
rfg_conf = confusion_matrix(y_test, rfg_pred)
rfg_report = classification_report(y_test, rfg_pred)
rfg_acc = round(accuracy_score(y_test, rfg_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{rfg_conf}")
print(f"\nClassification Report : \n\n{rfg_report}")
print(f"\nThe Accuracy of Random Forest Classifier is {rfg_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 4  8]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50        12
#            1       0.85      1.00      0.92        44
#
#     accuracy                           0.86        56
#    macro avg       0.92      0.67      0.71        56
# weighted avg       0.88      0.86      0.83        56
#
#
# The Accuracy of Random Forest Classifier is 85.71 %

# %% [markdown]
# <a id="19"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">K Nearest Neighbors Model</p>

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(x_train, y_train)
knn_pred = knn.predict(x_test)
knn_conf = confusion_matrix(y_test, knn_pred)
knn_report = classification_report(y_test, knn_pred)
knn_acc = round(accuracy_score(y_test, knn_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{knn_conf}")
print(f"\nClassification Report : \n\n{knn_report}")
print(f"\nThe Accuracy of K Nearest Neighbors Classifier is {knn_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 9  3]
#  [ 1 43]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82        12
#            1       0.93      0.98      0.96        44
#
#     accuracy                           0.93        56
#    macro avg       0.92      0.86      0.89        56
# weighted avg       0.93      0.93      0.93        56
#
#
# The Accuracy of K Nearest Neighbors Classifier is 92.86 %

# %% [markdown]
# <a id="20"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Extreme Gradient Boosting Model</p>

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(use_label_encoder = False)
xgb.fit(x_train, y_train)
xgb_pred = xgb.predict(x_test)
xgb_conf = confusion_matrix(y_test, xgb_pred)
xgb_report = classification_report(y_test, xgb_pred)
xgb_acc = round(accuracy_score(y_test, xgb_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{xgb_conf}")
print(f"\nClassification Report : \n\n{xgb_report}")
print(f"\nThe Accuracy of Extreme Gradient Boosting Classifier is {xgb_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 7  5]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.58      0.74        12
#            1       0.90      1.00      0.95        44
#
#     accuracy                           0.91        56
#    macro avg       0.95      0.79      0.84        56
# weighted avg       0.92      0.91      0.90        56
#
#
# The Accuracy of Extreme Gradient Boosting Classifier is 91.07 %

# %% [markdown]
# <a id="21"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Neural Network Architecture</p>

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

regularization_parameter = 0.003

neural_model = Sequential([tf.keras.layers.Dense(units=32, input_dim=(x_train.shape[-1]), activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=64, activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=128, activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dropout(0.3),
                    tf.keras.layers.Dense(units=16,activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=1, activation="sigmoid")
                    ])

print(neural_model.summary())
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_35 (Dense)             (None, 32)                512
# _________________________________________________________________
# dense_36 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 16)                2064
# _________________________________________________________________
# dense_39 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 13,025
# Trainable params: 13,025
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get("accuracy") == 1.0):
            print("\nAccuracy is 100% so canceling training!")
            self.model.stop_training = True

callbacks = myCallback()


neural_model.compile(optimizer = Adam(learning_rate = 0.001), 
                     loss = "binary_crossentropy", 
                     metrics = ["accuracy"])

history = neural_model.fit(x_train, y_train,
                           epochs = 150,
                           verbose = 1,
                           batch_size = 64,
                           validation_data = (x_test, y_test),
                           callbacks = [callbacks])
# Out:
# Epoch 1/150
# 4/4 [==============================] - 1s 88ms/step - loss: 4.4727 - accuracy: 0.5273 - val_loss: 4.3390 - val_accuracy: 0.7857
# Epoch 2/150
# 4/4 [==============================] - 0s 14ms/step - loss: 4.2609 - accuracy: 0.8591 - val_loss: 4.1870 - val_accuracy: 0.7857
# Epoch 3/150
# 4/4 [==============================] - 0s 15ms/step - loss: 4.0838 - accuracy: 0.8818 - val_loss: 4.0566 - val_accuracy: 0.7857
# Epoch 4/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.9346 - accuracy: 0.8818 - val_loss: 3.9378 - val_accuracy: 0.7857
# Epoch 5/150
# 4/4 [==============================] - 0s 14ms/step - loss: 3.7934 - accuracy: 0.8818 - val_loss: 3.8248 - val_accuracy: 0.7857
# Epoch 6/150
# 4/4 [==============================] - 0s 14ms/step - loss: 3.6562 - accuracy: 0.8818 - val_loss: 3.7166 - val_accuracy: 0.7857
# Epoch 7/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.5442 - accuracy: 0.8818 - val_loss: 3.6087 - val_accuracy: 0.7857
# Epoch 8/150
# 4/4 [==============================] - 0s 14ms/step - loss: 3.4146 - accuracy: 0.8818 - val_loss: 3.4975 - val_accuracy: 0.7857
# Epoch 9/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.3006 - accuracy: 0.8818 - val_loss: 3.3803 - val_accuracy: 0.7857
# Epoch 10/150
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1868 - accuracy: 0.8818 - val_loss: 3.2621 - val_accuracy: 0.7857
# Epoch 11/150
# 4/4 [==============================] - 0s 20ms/step - loss: 3.0814 - accuracy: 0.8818 - val_loss: 3.1452 - val_accuracy: 0.7857
# Epoch 12/150
# 4/4 [==============================] - 0s 34ms/step - loss: 2.9524 - accuracy: 0.8818 - val_loss: 3.0291 - val_accuracy: 0.7857
# Epoch 13/150
# 4/4 [==============================] - 0s 26ms/step - loss: 2.8554 - accuracy: 0.8818 - val_loss: 2.9192 - val_accuracy: 0.7857
# Epoch 14/150
# 4/4 [==============================] - 0s 22ms/step - loss: 2.7543 - accuracy: 0.8818 - val_loss: 2.8119 - val_accuracy: 0.7857
# Epoch 15/150
# 4/4 [==============================] - 0s 35ms/step - loss: 2.6533 - accuracy: 0.8818 - val_loss: 2.7115 - val_accuracy: 0.7857
# Epoch 16/150
# 4/4 [==============================] - 0s 27ms/step - loss: 2.5452 - accuracy: 0.8818 - val_loss: 2.6156 - val_accuracy: 0.7857
# Epoch 17/150
# 4/4 [==============================] - 0s 25ms/step - loss: 2.4571 - accuracy: 0.8818 - val_loss: 2.5235 - val_accuracy: 0.7857
# Epoch 18/150
# 4/4 [==============================] - 0s 34ms/step - loss: 2.3608 - accuracy: 0.8818 - val_loss: 2.4305 - val_accuracy: 0.7857
# Epoch 19/150
# 4/4 [==============================] - 0s 36ms/step - loss: 2.2637 - accuracy: 0.8818 - val_loss: 2.3390 - val_accuracy: 0.7857
# Epoch 20/150
# 4/4 [==============================] - 0s 22ms/step - loss: 2.1729 - accuracy: 0.8818 - val_loss: 2.2508 - val_accuracy: 0.7857
# Epoch 21/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.0944 - accuracy: 0.8818 - val_loss: 2.1652 - val_accuracy: 0.7857
# Epoch 22/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.0120 - accuracy: 0.8818 - val_loss: 2.0809 - val_accuracy: 0.7857
# Epoch 23/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.9305 - accuracy: 0.8818 - val_loss: 1.9999 - val_accuracy: 0.7857
# Epoch 24/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.8408 - accuracy: 0.8818 - val_loss: 1.9195 - val_accuracy: 0.7857
# Epoch 25/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.7748 - accuracy: 0.8818 - val_loss: 1.8434 - val_accuracy: 0.7857
# Epoch 26/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.6949 - accuracy: 0.8818 - val_loss: 1.7705 - val_accuracy: 0.7857
# Epoch 27/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.6315 - accuracy: 0.8818 - val_loss: 1.7027 - val_accuracy: 0.7857
# Epoch 28/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.5594 - accuracy: 0.8818 - val_loss: 1.6337 - val_accuracy: 0.7857
# Epoch 29/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.4925 - accuracy: 0.8818 - val_loss: 1.5695 - val_accuracy: 0.7857
# Epoch 30/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.4314 - accuracy: 0.8818 - val_loss: 1.5082 - val_accuracy: 0.7857
# Epoch 31/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3720 - accuracy: 0.8818 - val_loss: 1.4494 - val_accuracy: 0.7857
# Epoch 32/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3138 - accuracy: 0.8818 - val_loss: 1.3938 - val_accuracy: 0.7857
# Epoch 33/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.2606 - accuracy: 0.8818 - val_loss: 1.3372 - val_accuracy: 0.7857
# Epoch 34/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.2071 - accuracy: 0.8818 - val_loss: 1.2829 - val_accuracy: 0.7857
# Epoch 35/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.1505 - accuracy: 0.8818 - val_loss: 1.2302 - val_accuracy: 0.7857
# Epoch 36/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.1028 - accuracy: 0.8818 - val_loss: 1.1829 - val_accuracy: 0.7857
# Epoch 37/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0628 - accuracy: 0.8818 - val_loss: 1.1376 - val_accuracy: 0.7857
# Epoch 38/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0214 - accuracy: 0.8818 - val_loss: 1.0932 - val_accuracy: 0.7857
# Epoch 39/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9802 - accuracy: 0.8818 - val_loss: 1.0524 - val_accuracy: 0.7857
# Epoch 40/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9424 - accuracy: 0.8955 - val_loss: 1.0143 - val_accuracy: 0.7857
# Epoch 41/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9004 - accuracy: 0.8864 - val_loss: 0.9806 - val_accuracy: 0.7857
# Epoch 42/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8685 - accuracy: 0.8818 - val_loss: 0.9490 - val_accuracy: 0.7857
# Epoch 43/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.8440 - accuracy: 0.8864 - val_loss: 0.9219 - val_accuracy: 0.7857
# Epoch 44/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8156 - accuracy: 0.8818 - val_loss: 0.8944 - val_accuracy: 0.7857
# Epoch 45/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7928 - accuracy: 0.9045 - val_loss: 0.8679 - val_accuracy: 0.7857
# Epoch 46/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7712 - accuracy: 0.9000 - val_loss: 0.8442 - val_accuracy: 0.7857
# Epoch 47/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7490 - accuracy: 0.9000 - val_loss: 0.8229 - val_accuracy: 0.7857
# Epoch 48/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7248 - accuracy: 0.9045 - val_loss: 0.8029 - val_accuracy: 0.7857
# Epoch 49/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7097 - accuracy: 0.9045 - val_loss: 0.7845 - val_accuracy: 0.8036
# Epoch 50/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6895 - accuracy: 0.8955 - val_loss: 0.7677 - val_accuracy: 0.8036
# Epoch 51/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6744 - accuracy: 0.9091 - val_loss: 0.7504 - val_accuracy: 0.8036
# Epoch 52/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6543 - accuracy: 0.9091 - val_loss: 0.7351 - val_accuracy: 0.8036
# Epoch 53/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6399 - accuracy: 0.9136 - val_loss: 0.7222 - val_accuracy: 0.8036
# Epoch 54/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6202 - accuracy: 0.9091 - val_loss: 0.7078 - val_accuracy: 0.8393
# Epoch 55/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6122 - accuracy: 0.9182 - val_loss: 0.6948 - val_accuracy: 0.8393
# Epoch 56/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5979 - accuracy: 0.9136 - val_loss: 0.6835 - val_accuracy: 0.8393
# Epoch 57/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5860 - accuracy: 0.9091 - val_loss: 0.6699 - val_accuracy: 0.8929
# Epoch 58/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5742 - accuracy: 0.9182 - val_loss: 0.6569 - val_accuracy: 0.8929
# Epoch 59/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5624 - accuracy: 0.9227 - val_loss: 0.6465 - val_accuracy: 0.8929
# Epoch 60/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5576 - accuracy: 0.9227 - val_loss: 0.6361 - val_accuracy: 0.8929
# Epoch 61/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5430 - accuracy: 0.9227 - val_loss: 0.6275 - val_accuracy: 0.8929
# Epoch 62/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5338 - accuracy: 0.9182 - val_loss: 0.6195 - val_accuracy: 0.8929
# Epoch 63/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5289 - accuracy: 0.9182 - val_loss: 0.6095 - val_accuracy: 0.8929
# Epoch 64/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5153 - accuracy: 0.9273 - val_loss: 0.6004 - val_accuracy: 0.8929
# Epoch 65/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5125 - accuracy: 0.9273 - val_loss: 0.5936 - val_accuracy: 0.8929
# Epoch 66/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4999 - accuracy: 0.9227 - val_loss: 0.5862 - val_accuracy: 0.8929
# Epoch 67/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4980 - accuracy: 0.9273 - val_loss: 0.5785 - val_accuracy: 0.8929
# Epoch 68/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4901 - accuracy: 0.9318 - val_loss: 0.5716 - val_accuracy: 0.8929
# Epoch 69/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4788 - accuracy: 0.9318 - val_loss: 0.5649 - val_accuracy: 0.8929
# Epoch 70/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4746 - accuracy: 0.9273 - val_loss: 0.5587 - val_accuracy: 0.8929
# Epoch 71/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4694 - accuracy: 0.9273 - val_loss: 0.5527 - val_accuracy: 0.8929
# Epoch 72/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4620 - accuracy: 0.9273 - val_loss: 0.5469 - val_accuracy: 0.8929
# Epoch 73/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4526 - accuracy: 0.9318 - val_loss: 0.5416 - val_accuracy: 0.8929
# Epoch 74/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4516 - accuracy: 0.9318 - val_loss: 0.5367 - val_accuracy: 0.9107
# Epoch 75/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4482 - accuracy: 0.9455 - val_loss: 0.5313 - val_accuracy: 0.9107
# Epoch 76/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4442 - accuracy: 0.9409 - val_loss: 0.5260 - val_accuracy: 0.9107
# Epoch 77/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4313 - accuracy: 0.9409 - val_loss: 0.5219 - val_accuracy: 0.9107
# Epoch 78/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4343 - accuracy: 0.9409 - val_loss: 0.5173 - val_accuracy: 0.9107
# Epoch 79/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4228 - accuracy: 0.9409 - val_loss: 0.5124 - val_accuracy: 0.9107
# Epoch 80/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4216 - accuracy: 0.9455 - val_loss: 0.5086 - val_accuracy: 0.9107
# Epoch 81/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4176 - accuracy: 0.9409 - val_loss: 0.5039 - val_accuracy: 0.9107
# Epoch 82/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4101 - accuracy: 0.9409 - val_loss: 0.4983 - val_accuracy: 0.9107
# Epoch 83/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4075 - accuracy: 0.9455 - val_loss: 0.4939 - val_accuracy: 0.9107
# Epoch 84/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4053 - accuracy: 0.9409 - val_loss: 0.4913 - val_accuracy: 0.9107
# Epoch 85/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4055 - accuracy: 0.9500 - val_loss: 0.4899 - val_accuracy: 0.9107
# Epoch 86/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3953 - accuracy: 0.9409 - val_loss: 0.4881 - val_accuracy: 0.8929
# Epoch 87/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3899 - accuracy: 0.9364 - val_loss: 0.4866 - val_accuracy: 0.8929
# Epoch 88/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3862 - accuracy: 0.9318 - val_loss: 0.4837 - val_accuracy: 0.9107
# Epoch 89/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3869 - accuracy: 0.9318 - val_loss: 0.4791 - val_accuracy: 0.9107
# Epoch 90/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3845 - accuracy: 0.9455 - val_loss: 0.4730 - val_accuracy: 0.9107
# Epoch 91/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3828 - accuracy: 0.9500 - val_loss: 0.4684 - val_accuracy: 0.9107
# Epoch 92/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3755 - accuracy: 0.9500 - val_loss: 0.4628 - val_accuracy: 0.9107
# Epoch 93/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3770 - accuracy: 0.9455 - val_loss: 0.4586 - val_accuracy: 0.9107
# Epoch 94/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3693 - accuracy: 0.9500 - val_loss: 0.4556 - val_accuracy: 0.9107
# Epoch 95/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3702 - accuracy: 0.9500 - val_loss: 0.4536 - val_accuracy: 0.9107
# Epoch 96/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3666 - accuracy: 0.9455 - val_loss: 0.4517 - val_accuracy: 0.9107
# Epoch 97/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3644 - accuracy: 0.9455 - val_loss: 0.4512 - val_accuracy: 0.9107
# Epoch 98/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3669 - accuracy: 0.9455 - val_loss: 0.4482 - val_accuracy: 0.9107
# Epoch 99/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3638 - accuracy: 0.9500 - val_loss: 0.4441 - val_accuracy: 0.9107
# Epoch 100/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3558 - accuracy: 0.9500 - val_loss: 0.4405 - val_accuracy: 0.9107
# Epoch 101/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3588 - accuracy: 0.9500 - val_loss: 0.4372 - val_accuracy: 0.9107
# Epoch 102/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3466 - accuracy: 0.9545 - val_loss: 0.4363 - val_accuracy: 0.9107
# Epoch 103/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3523 - accuracy: 0.9500 - val_loss: 0.4336 - val_accuracy: 0.9107
# Epoch 104/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3465 - accuracy: 0.9545 - val_loss: 0.4306 - val_accuracy: 0.9107
# Epoch 105/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3459 - accuracy: 0.9545 - val_loss: 0.4301 - val_accuracy: 0.9107
# Epoch 106/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3401 - accuracy: 0.9500 - val_loss: 0.4281 - val_accuracy: 0.9107
# Epoch 107/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3408 - accuracy: 0.9500 - val_loss: 0.4243 - val_accuracy: 0.9107
# Epoch 108/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3369 - accuracy: 0.9500 - val_loss: 0.4216 - val_accuracy: 0.9107
# Epoch 109/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3345 - accuracy: 0.9500 - val_loss: 0.4196 - val_accuracy: 0.9107
# Epoch 110/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3374 - accuracy: 0.9500 - val_loss: 0.4162 - val_accuracy: 0.9107
# Epoch 111/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3303 - accuracy: 0.9500 - val_loss: 0.4141 - val_accuracy: 0.9107
# Epoch 112/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3284 - accuracy: 0.9500 - val_loss: 0.4135 - val_accuracy: 0.9107
# Epoch 113/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3243 - accuracy: 0.9500 - val_loss: 0.4126 - val_accuracy: 0.9107
# Epoch 114/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3265 - accuracy: 0.9500 - val_loss: 0.4117 - val_accuracy: 0.9107
# Epoch 115/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3257 - accuracy: 0.9500 - val_loss: 0.4108 - val_accuracy: 0.9107
# Epoch 116/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3257 - accuracy: 0.9500 - val_loss: 0.4088 - val_accuracy: 0.8929
# Epoch 117/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3212 - accuracy: 0.9545 - val_loss: 0.4072 - val_accuracy: 0.8929
# Epoch 118/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3201 - accuracy: 0.9545 - val_loss: 0.4045 - val_accuracy: 0.8929
# Epoch 119/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3153 - accuracy: 0.9545 - val_loss: 0.4037 - val_accuracy: 0.8929
# Epoch 120/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3131 - accuracy: 0.9500 - val_loss: 0.4007 - val_accuracy: 0.8929
# Epoch 121/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3118 - accuracy: 0.9500 - val_loss: 0.3987 - val_accuracy: 0.8929
# Epoch 122/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3101 - accuracy: 0.9500 - val_loss: 0.3959 - val_accuracy: 0.8929
# Epoch 123/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3081 - accuracy: 0.9591 - val_loss: 0.3944 - val_accuracy: 0.8929
# Epoch 124/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3057 - accuracy: 0.9500 - val_loss: 0.3946 - val_accuracy: 0.8929
# Epoch 125/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3046 - accuracy: 0.9455 - val_loss: 0.3922 - val_accuracy: 0.8929
# Epoch 126/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3049 - accuracy: 0.9500 - val_loss: 0.3895 - val_accuracy: 0.8929
# Epoch 127/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3004 - accuracy: 0.9500 - val_loss: 0.3867 - val_accuracy: 0.8929
# Epoch 128/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2998 - accuracy: 0.9545 - val_loss: 0.3861 - val_accuracy: 0.8929
# Epoch 129/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3040 - accuracy: 0.9545 - val_loss: 0.3841 - val_accuracy: 0.8929
# Epoch 130/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2945 - accuracy: 0.9545 - val_loss: 0.3835 - val_accuracy: 0.8929
# Epoch 131/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2982 - accuracy: 0.9636 - val_loss: 0.3827 - val_accuracy: 0.8929
# Epoch 132/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2930 - accuracy: 0.9545 - val_loss: 0.3819 - val_accuracy: 0.8929
# Epoch 133/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2968 - accuracy: 0.9636 - val_loss: 0.3801 - val_accuracy: 0.8929
# Epoch 134/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2937 - accuracy: 0.9545 - val_loss: 0.3783 - val_accuracy: 0.8929
# Epoch 135/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2887 - accuracy: 0.9500 - val_loss: 0.3790 - val_accuracy: 0.8929
# Epoch 136/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2860 - accuracy: 0.9591 - val_loss: 0.3799 - val_accuracy: 0.8929
# Epoch 137/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2899 - accuracy: 0.9545 - val_loss: 0.3783 - val_accuracy: 0.8929
# Epoch 138/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2811 - accuracy: 0.9545 - val_loss: 0.3776 - val_accuracy: 0.8929
# Epoch 139/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2923 - accuracy: 0.9500 - val_loss: 0.3765 - val_accuracy: 0.8929
# Epoch 140/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2855 - accuracy: 0.9591 - val_loss: 0.3740 - val_accuracy: 0.8929
# Epoch 141/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2837 - accuracy: 0.9500 - val_loss: 0.3739 - val_accuracy: 0.8929
# Epoch 142/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2814 - accuracy: 0.9500 - val_loss: 0.3712 - val_accuracy: 0.9107
# Epoch 143/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2828 - accuracy: 0.9500 - val_loss: 0.3690 - val_accuracy: 0.9107
# Epoch 144/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2819 - accuracy: 0.9545 - val_loss: 0.3676 - val_accuracy: 0.9107
# Epoch 145/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2833 - accuracy: 0.9545 - val_loss: 0.3688 - val_accuracy: 0.9107
# Epoch 146/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2814 - accuracy: 0.9545 - val_loss: 0.3675 - val_accuracy: 0.9107
# Epoch 147/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2769 - accuracy: 0.9545 - val_loss: 0.3641 - val_accuracy: 0.9107
# Epoch 148/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2770 - accuracy: 0.9545 - val_loss: 0.3611 - val_accuracy: 0.9107
# Epoch 149/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2770 - accuracy: 0.9545 - val_loss: 0.3595 - val_accuracy: 0.9107
# Epoch 150/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2704 - accuracy: 0.9636 - val_loss: 0.3591 - val_accuracy: 0.9107

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs = range(len(acc)) # number of epochs

plt.figure(figsize=(20, 12))
plt.subplot(2,1,1)
plt.plot(epochs, acc, "yellow", label= "Training Accuracy")
plt.plot(epochs, val_acc, "black", label= "Validation Accuracy")
plt.title("Training and validation accuracy")
plt.legend()

plt.subplot(2,1,2)
plt.plot(epochs, loss, "yellow", label= "Training Loss")
plt.plot(epochs, val_loss, "black", label= "Validation Loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# <a id="22"></a>
# # <p style="padding:10px;background-color:#0f4c5c;margin:0;color:white;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Thank You</p>
#
#
# <p>
# <h3><font color="#0f4c5c">If you liked this notebook please upvote. Your feedback will be highly appreciated.</font></h3>
#
# <br>
#
# <h4><b>Author :</b></h4>
#
# <h3>Hasib Al Muzdadid</h3>
#
# <b>👉Shoot me mails :</b> muzdadid@gmail.com<br>
# <b>👉Connect on LinkedIn :</b> https://www.linkedin.com/in/hasibalmuzdadid <br>
# <b>👉Explore Github :</b> https://github.com/HasibAlMuzdadid
#
# </p>
